# %%
import pandas as pd
df=pd.read_csv("Motor_Vehicle_Collisions_-_Crashes.csv")
# Out:
# /var/folders/xr/82_smqfn2tj6c8jcx6cpnl_c0000gn/T/ipykernel_39930/3514536868.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Motor_Vehicle_Collisions_-_Crashes.csv")

# %%
df
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1        03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2        06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3        09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4        12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# ...             ...        ...        ...      ...        ...        ...
# 2059088  01/15/2024      13:00        NaN      NaN        NaN        NaN
# 2059089  01/15/2024      19:00      BRONX  10470.0  40.905815 -73.853040
# 2059090  01/15/2024      20:07   BROOKLYN  11229.0  40.597263 -73.951010
# 2059091  01/15/2024       8:30  MANHATTAN  10001.0  40.749786 -73.987780
# 2059092  01/15/2024      19:00        NaN      NaN  40.699580 -73.927800
#
#                         LOCATION           ON STREET NAME  \
# ...

# %%
null_counts = df.isnull().sum()

# %%
null_counts
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           640577
# ZIP CODE                          640825
# LATITUDE                          232656
# LONGITUDE                         232656
# LOCATION                          232656
# ON STREET NAME                    436122
# CROSS STREET NAME                 776168
# OFF STREET NAME                  1715344
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6673
# CONTRIBUTING FACTOR VEHICLE 2     317704
# CONTRIBUTING FACTOR VEHICLE 3    1912297
# CONTRIBUTING FACTOR VEHICLE 4    2026013
# CONTRIBUTING FACTOR VEHICLE 5    2050146
# ...

# %%
columns_to_drop = ['VEHICLE TYPE CODE 5', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 3']
df.drop(columns=columns_to_drop, inplace=True)

# %%
columns_to_drop = ['CONTRIBUTING FACTOR VEHICLE 5', 'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 3']
df.drop(columns=columns_to_drop, inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           640577
# ZIP CODE                          640825
# LATITUDE                          232656
# LONGITUDE                         232656
# LOCATION                          232656
# ON STREET NAME                    436122
# CROSS STREET NAME                 776168
# OFF STREET NAME                  1715344
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6673
# CONTRIBUTING FACTOR VEHICLE 2     317704
# COLLISION_ID                           0
# VEHICLE TYPE CODE 1                13393
# VEHICLE TYPE CODE 2               390962
# ...

# %%
columns_to_drop = ['OFF STREET NAME']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1        03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2        06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3        09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4        12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# ...             ...        ...        ...      ...        ...        ...
# 2059088  01/15/2024      13:00        NaN      NaN        NaN        NaN
# 2059089  01/15/2024      19:00      BRONX  10470.0  40.905815 -73.853040
# 2059090  01/15/2024      20:07   BROOKLYN  11229.0  40.597263 -73.951010
# 2059091  01/15/2024       8:30  MANHATTAN  10001.0  40.749786 -73.987780
# 2059092  01/15/2024      19:00        NaN      NaN  40.699580 -73.927800
#
#                         LOCATION           ON STREET NAME  \
# ...

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                          640577
# ZIP CODE                         640825
# LATITUDE                         232656
# LONGITUDE                        232656
# LOCATION                         232656
# ON STREET NAME                   436122
# CROSS STREET NAME                776168
# NUMBER OF PERSONS INJURED            18
# NUMBER OF PERSONS KILLED             31
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      6673
# CONTRIBUTING FACTOR VEHICLE 2    317704
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1               13393
# VEHICLE TYPE CODE 2              390962
# dtype: int64

# %%
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')

# %%
df.dtypes
# Out:
# CRASH DATE                       datetime64[ns]
# CRASH TIME                               object
# BOROUGH                                  object
# ZIP CODE                                 object
# LATITUDE                                float64
# LONGITUDE                               float64
# LOCATION                                 object
# ON STREET NAME                           object
# CROSS STREET NAME                        object
# NUMBER OF PERSONS INJURED               float64
# NUMBER OF PERSONS KILLED                float64
# NUMBER OF PEDESTRIANS INJURED             int64
# NUMBER OF PEDESTRIANS KILLED              int64
# NUMBER OF CYCLIST INJURED                 int64
# NUMBER OF CYCLIST KILLED                  int64
# NUMBER OF MOTORIST INJURED                int64
# NUMBER OF MOTORIST KILLED                 int64
# CONTRIBUTING FACTOR VEHICLE 1            object
# CONTRIBUTING FACTOR VEHICLE 2            object
# COLLISION_ID                              int64
# ...

# %%
df
# Out:
#         CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2021-09-11       2:39        NaN      NaN        NaN        NaN
# 1       2022-03-26      11:45        NaN      NaN        NaN        NaN
# 2       2022-06-29       6:55        NaN      NaN        NaN        NaN
# 3       2021-09-11       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4       2021-12-14       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# ...            ...        ...        ...      ...        ...        ...
# 2059088 2024-01-15      13:00        NaN      NaN        NaN        NaN
# 2059089 2024-01-15      19:00      BRONX  10470.0  40.905815 -73.853040
# 2059090 2024-01-15      20:07   BROOKLYN  11229.0  40.597263 -73.951010
# 2059091 2024-01-15       8:30  MANHATTAN  10001.0  40.749786 -73.987780
# 2059092 2024-01-15      19:00        NaN      NaN  40.699580 -73.927800
#
#                         LOCATION           ON STREET NAME  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2021-09-11       2:39        NaN      NaN        NaN        NaN
# 1       2022-03-26      11:45        NaN      NaN        NaN        NaN
# 2       2022-06-29       6:55        NaN      NaN        NaN        NaN
# 3       2021-09-11       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4       2021-12-14       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# ...            ...        ...        ...      ...        ...        ...
# 2059088 2024-01-15      13:00        NaN      NaN        NaN        NaN
# 2059089 2024-01-15      19:00      BRONX  10470.0  40.905815 -73.853040
# 2059090 2024-01-15      20:07   BROOKLYN  11229.0  40.597263 -73.951010
# 2059091 2024-01-15       8:30  MANHATTAN  10001.0  40.749786 -73.987780
# 2059092 2024-01-15      19:00        NaN      NaN  40.699580 -73.927800
#
#                         LOCATION           ON STREET NAME  \
# ...

# %%
df.dropna(subset=['LATITUDE'], inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                          444694
# ZIP CODE                         444916
# LATITUDE                              0
# LONGITUDE                             0
# LOCATION                              0
# ON STREET NAME                   380064
# CROSS STREET NAME                684132
# NUMBER OF PERSONS INJURED            16
# NUMBER OF PERSONS KILLED             28
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      6072
# CONTRIBUTING FACTOR VEHICLE 2    287458
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1               12230
# VEHICLE TYPE CODE 2              356613
# dtype: int64

# %%
df
# Out:
#         CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 3       2021-09-11       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4       2021-12-14       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# 6       2021-12-14      17:05        NaN      NaN  40.709183 -73.956825
# 7       2021-12-14       8:17      BRONX  10475.0  40.868160 -73.831480
# 8       2021-12-14      21:10   BROOKLYN  11207.0  40.671720 -73.897100
# ...            ...        ...        ...      ...        ...        ...
# 2059087 2024-01-13      18:30     QUEENS  11434.0  40.666840 -73.789410
# 2059089 2024-01-15      19:00      BRONX  10470.0  40.905815 -73.853040
# 2059090 2024-01-15      20:07   BROOKLYN  11229.0  40.597263 -73.951010
# 2059091 2024-01-15       8:30  MANHATTAN  10001.0  40.749786 -73.987780
# 2059092 2024-01-15      19:00        NaN      NaN  40.699580 -73.927800
#
#                         LOCATION              ON STREET NAME  \
# ...

# %%
columns_to_fill = ['BOROUGH']  
df[columns_to_fill] = df[columns_to_fill].fillna('not known')

# %%
columns_to_drop = ['ZIP CODE']
df.drop(columns=columns_to_drop, inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                               0
# LATITUDE                              0
# LONGITUDE                             0
# LOCATION                              0
# ON STREET NAME                   380064
# CROSS STREET NAME                684132
# NUMBER OF PERSONS INJURED            16
# NUMBER OF PERSONS KILLED             28
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      6072
# CONTRIBUTING FACTOR VEHICLE 2    287458
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1               12230
# VEHICLE TYPE CODE 2              356613
# dtype: int64

# %%
df.dropna(subset=['NUMBER OF PERSONS KILLED'], inplace=True)

# %%
df.dropna(subset=['NUMBER OF PERSONS INJURED'], inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                               0
# LATITUDE                              0
# LONGITUDE                             0
# LOCATION                              0
# ON STREET NAME                   380049
# CROSS STREET NAME                684110
# NUMBER OF PERSONS INJURED             0
# NUMBER OF PERSONS KILLED              0
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      6066
# CONTRIBUTING FACTOR VEHICLE 2    287431
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1               12225
# VEHICLE TYPE CODE 2              356585
# dtype: int64

# %%
df.dropna(subset=['VEHICLE TYPE CODE 2'], inplace=True)

# %%
df.dropna(subset=['VEHICLE TYPE CODE 1'], inplace=True)

# %%
df.dropna(subset=['CONTRIBUTING FACTOR VEHICLE 2'], inplace=True)

# %%
columns_to_fill = ['ON STREET NAME']  
df[columns_to_fill] = df[columns_to_fill].fillna('unknown')
columns_to_fill = ['CROSS STREET NAME']  
df[columns_to_fill] = df[columns_to_fill].fillna('unknown')

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# LATITUDE                         0
# LONGITUDE                        0
# LOCATION                         0
# ON STREET NAME                   0
# CROSS STREET NAME                0
# NUMBER OF PERSONS INJURED        0
# NUMBER OF PERSONS KILLED         0
# NUMBER OF PEDESTRIANS INJURED    0
# NUMBER OF PEDESTRIANS KILLED     0
# NUMBER OF CYCLIST INJURED        0
# NUMBER OF CYCLIST KILLED         0
# NUMBER OF MOTORIST INJURED       0
# NUMBER OF MOTORIST KILLED        0
# CONTRIBUTING FACTOR VEHICLE 1    0
# CONTRIBUTING FACTOR VEHICLE 2    0
# COLLISION_ID                     0
# VEHICLE TYPE CODE 1              0
# VEHICLE TYPE CODE 2              0
# dtype: int64

# %%
columns_to_drop = ['LOCATION']
df.drop(columns=columns_to_drop, inplace=True)

# %%
# Out:
#         CRASH DATE CRASH TIME        BOROUGH   LATITUDE  LONGITUDE  \
# 6       2021-12-14      17:05      not known  40.709183 -73.956825
# 7       2021-12-14       8:17          BRONX  40.868160 -73.831480
# 9       2021-12-14      14:58      MANHATTAN  40.751440 -73.973970
# 11      2021-12-14      16:50         QUEENS  40.675884 -73.755770
# 14      2021-12-14      23:10         QUEENS  40.666840 -73.789410
# ...            ...        ...            ...        ...        ...
# 2059083 2024-01-13      22:00       BROOKLYN  40.601192 -73.955910
# 2059084 2024-01-15      23:30         QUEENS  40.688465 -73.803870
# 2059085 2024-01-15      19:50  STATEN ISLAND  40.521072 -74.236140
# 2059086 2024-01-15       3:15         QUEENS  40.677006 -73.812610
# 2059091 2024-01-15       8:30      MANHATTAN  40.749786 -73.987780
#
#                      ON STREET NAME       CROSS STREET NAME  \
# 6        BROOKLYN QUEENS EXPRESSWAY                 unknown
# ...
